# %%
import nltk
import time
import string
import random
import pickle
import unicodecsv as csv

# %%
def timeit(func):
    def wrapper(*args, **kwargs):
        start  = time.time()
        result = func(*args, **kwargs)
        finit  = time.time()
        return result, finit-start
    return wrapper

class ProductCorpus(object):
    """
    Simple product "CorpusReader" that implements a CorpusReader-like
    interface including products, words, categories, etc.
    """

    def __init__(self, path):
        self.path = path
        self._categories = None

    def __iter__(self):
        """
        Iterates through each product in the dataset
        """
        with open(self.path, 'r') as data:
            reader = csv.DictReader(data)
            for idx, row in enumerate(reader):
                row['rowid'] = idx + 1
                yield row

    def categories(self):
        if not self._categories:
            self._categories = set(row['category'] for row in self)
        return self._categories

    def products(self, categories=None):
        if not categories:
            categories = self.categories()
        elif isinstance(categories, basestring):
            categories = [categories]

        return filter(lambda x: x['category'] in categories, self)

# Create feature extractor methodology
def normalize_words(document):
    """
    Expects as input a list of words that make up a document. This will
    yield only lowercase significant words (excluding stopwords and
    punctuation) and will lemmatize all words to ensure that we have word
    forms that are standardized.
    """
    stopwords  = set(nltk.corpus.stopwords.words('english'))
    lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
    for token in document:
        token = token.lower()
        if token in string.punctuation: continue
        if token in stopwords: continue
        yield lemmatizer.lemmatize(token)

def product_features(product):
    name = nltk.FreqDist(normalize_words(nltk.wordpunct_tokenize(product['name'])))
    desc = nltk.FreqDist(normalize_words(nltk.wordpunct_tokenize(product['description'])))
    feats = {}
    for word in name.keys():
        feats['name(%s)' % word] = True

    for word in desc.keys():
        feats['description(%s)' % word] = True
    return feats

def generate_datasets(path):
    """
    Returns 10 percent of the corpus as test set and the rest for training.
    """

    corpus = ProductCorpus(path)
    
    
    prods  = [(product_features(product), product['category'])
                for product in corpus.products()]
    offset = len(prods)/10
    random.shuffle(prods)

    return prods[:offset], prods[offset:]

@timeit
def build_maxent(training, outpath):
    classifier = nltk.MaxentClassifier.train(training,
                    algorithm='megam', trace=2, gaussian_prior_sigma=1)

    with open(outpath, 'wb') as out:
        pickle.dump(classifier, out)

    return classifier

@timeit
def build_bayes(training, outpath):
    classifier = nltk.NaiveBayesClassifier.train(training)

    with open(outpath, 'wb') as out:
        pickle.dump(classifier, out)

    return classifier

@timeit
def build_dtree(training, outpath):
    classifier = nltk.DecisionTreeClassifier.train(training)

    with open(outpath, 'wb') as out:
        pickle.dump(classifier, out)

    return classifier

# %%
train, test = generate_datasets('products.csv')

# %%
#maxent, mdelta = build_maxent(train, 'products_maxent.pickle')
bayes,  bdelta = build_bayes(train, 'products_bayes.pickle')
# dtree,  ddelta = build_dtree(train, 'products_dtree.pickle')

# %%
#print "Maximum Entropy took %0.3f seconds to train" % mdelta
#print "    Accuracy %0.3f%%" % (nltk.classify.accuracy(maxent, test) * 100)
#print
#print maxent.show_most_informative_features()

print "Naive Bayes took %0.3f seconds to train" % bdelta
print "    Accuracy %0.3f%%" % (nltk.classify.accuracy(bayes, test) * 100)
print


# print "Decision Tree took %0.3f seconds to train" % ddelta
# print "    Accuracy %0.3f%%" % (nltk.classify.accuracy(dtree, test) * 100)
# print
# Out:
# Naive Bayes took 17.291 seconds to train
#     Accuracy 48.681%

# %%
devtest_names =  #

# %%
errors = []
for (name, tag) in devtest_names:
    guess = classifier.classify(gender_features(name))
    if guess != tag:
        errors.append( (tag, guess, name) )
# Out:
# [({u'name(amazon)': True,
#    u'name(com)': True,
#    u'name(instant)': True,
#    u'name(lawrence)': True,
#    u'name(marc)': True,
#    u'name(pig)': True,
#    u'name(video)': True},
#   u''),
#  ({u'name(59)': True,
#    u'name(baby)': True,
#    u'name(claus)': True,
#    u'name(eskimo)': True,
#    u'name(international)': True,
#    u'name(santa)': True,
#    u'name(sc)': True,
#    u'name(snow)': True},
#   u''),
#  ({u'description(album)': True,
#    u'description(cd)': True,
#    u'description(george)': True,
#    u'description(piece)': True,
#    u'description(stone)': True,
#    u'description(u)': True,
#    u'name(piece)': True},
#   u''),
#  ({u'description(),)': True,
#    u'description().)': True,
#    u'description(--)': True,
#    u'description(...)': True,
#    u'description(1941)': True,
#    u'description(1971)': True,
#    u'description(1979)': True,
#    u'description(1987)': True,
#    u'description(1989)': True,
#    u'description(6)': True,
#    u'description(accurate)': True,
#    u'description(andrew)': True,
#    u'description(astringently)': True,
#    u'description(austria)': True,
#    u'description(autobiography)': True,
#    u'description(balanced)': True,
#    u'description(become)': True,
#    u'description(bickley)': True,
#    u'description(blythe)': True,
#    u'description(book)': True,
#    u'description(born)': True,
#    u'description(british)': True,
#    u'description(canterbury)': True,
#    u'description(certainly)': True,
#    u'description(classic)': True,
#    u'description(college)': True,
#    u'description(commentator)': True,
#    u'description(commitment)': True,
#    u'description(condemned)': True,
#    u'description(containing)': True,
#    u'description(cornelius)': True,
#    u'description(crystalline)': True,
#    u'description(defies)': True,
#    u'description(definition)': True,
#    u'description(dog)': True,
#    u'description(edition)': True,
#    u'description(educated)': True,
#    u'description(element)': True,
#    u'description(england)': True,
#    u'description(entirely)': True,
#    u'description(exeter)': True,
#    u'description(exile)': True,
#    u'description(fiction)': True,
#    u'description(generally)': True,
#    u'description(genuine)': True,
#    u'description(gerontius)': True,
#    u'description(gorgeously)': True,
#    u'description(hall)': True,
#    u'description(hamilton)': True,
#    u'description(harvey)': True,
#    u'description(hawkridge)': True,
#    u'description(house)': True,
#    u'description(include)': True,
#    u'description(islander)': True,
#    u'description(italy)': True,
#    u'description(james)': True,
#    u'description(kent)': True,
#    u'description(king)': True,
#    u'description(known)': True,
#    u'description(landscape)': True,
#    u'description(literary)': True,
#    u'description(lived)': True,
#    u'description(london)': True,
#    u'description(mount)': True,
#    u'description(moved)': True,
#    u'description(mysterious)': True,
#    u'description(new)': True,
#    u'description(november)': True,
#    u'description(one)': True,
#    u'description(original)': True,
#    u'description(oxford)': True,
#    u'description(paperback)': True,
#    u'description(passion)': True,
#    u'description(paterson)': True,
#    u'description(perception)': True,
#    u'description(personal)': True,
#    u'description(philippine)': True,
#    u'description(recently)': True,
#    u'description(reclusive)': True,
#    u'description(refers)': True,
#    u'description(remote)': True,
#    u'description(responsive)': True,
#    u'description(ronald)': True,
#    u'description(school)': True,
#    u'description(science)': True,
#    u'description(sharing)': True,
#    u'description(since)': True,
#    u'description(story)': True,
#    u'description(supurb)': True,
#    u'description(sussex)': True,
#    u'description(text)': True,
#    u'description(time)': True,
#    u'description(travel)': True,
#    u'description(unforgetable)': True,
#    u'description(view)': True,
#    u'description(war)': True,
#    u'description(windlesham)': True,
#    u'description(work)': True,
#    u'description(writing)': True,
#    u'description(written)': True,
#    u'description(york)': True,
#    u'name(island)': True,
#    u'name(passion)': True,
#    u'name(philippine)': True,
#    u'name(playing)': True,
#    u'name(solitude)': True,
#    u'name(water)': True},
#   u''),
#  ({u'description(--)': True,
#    u'description(.")': True,
#    u'description(1789)': True,
#    u'description(1834)': True,
#    u'description(1835)': True,
#    u'description(2000)': True,
#    u'description(aboard)': True,
#    u'description(accurate)': True,
#    u'description(action)': True,
#    u'description(adventure)': True,
#    u'description(afloat)': True,
#    u'description(alternate)': True,
#    u'description(anonymously)': True,
#    u'description(best)': True,
#    u'description(blackwood)': True,
#    u'description(book)': True,
#    u'description(british)': True,
#    u'description(business)': True,
#    u'description(caribbean)': True,
#    u'description(century)': True,
#    u'description(character)': True,
#    u'description(colonial)': True,
#    u'description(cooper)': True,
#    u'description(copyright)': True,
#    u'description(cringle)': True,
#    u'description(digest)': True,
#    u'description(dynamic)': True,
#    u'description(early)': True,
#    u'description(edition)': True,
#    u'description(episodic)': True,
#    u'description(exciting)': True,
#    u'description(fan)': True,
#    u'description(fiction)': True,
#    u'description(find)': True,
#    u'description(first)': True,
#    u'description(follows)': True,
#    u'description(fun)': True,
#    u'description(hand)': True,
#    u'description(historical)': True,
#    u'description(history)': True,
#    u'description(hm)': True,
#    u'description(inc)': True,
#    u'description(indian)': True,
#    u'description(indie)': True,
#    u'description(information)': True,
#    u'description(jamaica)': True,
#    u'description(knowledge)': True,
#    u'description(land)': True,
#    u'description(later)': True,
#    u'description(life)': True,
#    u'description(log)': True,
#    u'description(magazine)': True,
#    u'description(manager)': True,
#    u'description(maritime)': True,
#    u'description(marryat)': True,
#    u'description(melded)': True,
#    u'description(merchant)': True,
#    u'description(michael)': True,
#    u'description(midshipman)': True,
#    u'description(mind)': True,
#    u'description(much)': True,
#    u'description(nineteenth)': True,
#    u'description(novel)': True,
#    u'description(one)': True,
#    u'description(paperback)': True,
#    u'description(part)': True,
#    u'description(period)': True,
#    u'description(picture)': True,
#    u'description(pirate)': True,
#    u'description(plantation)': True,
#    u'description(print)': True,
#    u'description(published)': True,
#    u'description(rank)': True,
#    u'description(reader)': True,
#    u'description(reed)': True,
#    u'description(refers)': True,
#    u'description(said)': True,
#    u'description(scott)': True,
#    u'description(sea)': True,
#    u'description(series)': True,
#    u'description(serving)': True,
#    u'description(shape)': True,
#    u'description(shore)': True,
#    u'description(sketch)': True,
#    u'description(spent)': True,
#    u'description(story)': True,
#    u'description(surpass)': True,
#    u'description(tale)': True,
#    u'description(text)': True,
#    u'description(title)': True,
#    u'description(together)': True,
#    u'description(tom)': True,
#    u'description(took)': True,
#    u'description(torch)': True,
#    u'description(tropical)': True,
#    u'description(unavailable)': True,
#    u'description(west)': True,
#    u'description(world)': True,
#    u'description(year)': True,
#    u'name(cringle)': True,
#    u'name(log)': True,
#    u'name(tom)': True},
#   u''),
#  ({u'description(beautiful)': True,
#    u'description(bed)': True,
#    u'description(blend)': True,
#    u'description(braided)': True,
#    u'description(classic)': True,
#    u'description(color)': True,
#    u'description(come)': True,
#    u'description(comfort)': True,
#    u'description(comforter)': True,
#    u'description(cord)': True,
#    u'description(cotton)': True,
#    u'description(deluxe)': True,
#    u'description(exta)': True,
#    u'description(fashion)': True,
#    u'description(fiber)': True,
#    u'description(fill)': True,
#    u'description(finish)': True,
#    u'description(finished)': True,
#    u'description(includes)': True,
#    u'description(jacquard)': True,
#    u'description(lofty)': True,
#    u'description(look)': True,
#    u'description(luxurious)': True,
#    u'description(olyester)': True,
#    u'description(overstuffed)': True,
#    u'description(p)': True,
#    u'description(pillow)': True,
#    u'description(poly)': True,
#    u'description(revers)': True,
#    u'description(set)': True,
#    u'description(sham)': True,
#    u'description(skirt)': True,
#    u'description(soft)': True,
#    u'description(two)': True,
#    u'description(vibrant)': True,
#    u'description(woven)': True,
#    u'name(4)': True,
#    u'name(comforter)': True,
#    u'name(floral)': True,
#    u'name(jacquard)': True,
#    u'name(malibu)': True,
#    u'name(navy)': True,
#    u'name(piece)': True,
#    u'name(sage)': True,
#    u'name(set)': True,
#    u'name(shore)': True},
#   u''),
#  ({u'description(").)': True,
#    u'description(,")': True,
#    u'description(--)': True,
#    u'description(.")': True,
#    u'description(1962)': True,
#    u'description(1965)': True,
#    u'description(1993)': True,
#    u'description(60)': True,
#    u'description(63)': True,
#    u'description(aforementioned)': True,
#    u'description(albert)': True,
#    u'description(already)': True,
#    u'description(alto)': True,
#    u'description(another)': True,
#    u'description(backing)': True,
#    u'description(ballot)': True,
#    u'description(band)': True,
#    u'description(bass)': True,
#    u'description(became)': True,
#    u'description(belong)': True,
#    u'description(blue)': True,
#    u'description(breeze)': True,
#    u'description(came)': True,
#    u'description(cd)': True,
#    u'description(classic)': True,
#    u'description(clean)': True,
#    u'description(clear)': True,
#    u'description(collection)': True,
#    u'description(collins)': True,
#    u'description(cone)': True,
#    u'description(considerable)': True,
#    u'description(contrast)': True,
#    u'description(cool)': True,
#    u'description(coolest)': True,
#    u'description(couple)': True,
#    u'description(dozen)': True,
#    u'description(drum)': True,
#    u'description(dyin)': True,
#    u'description(early)': True,
#    u'description(element)': True,
#    u'description(entreaty)': True,
#    u'description(even)': True,
#    u'description(example)': True,
#    u'description(exception)': True,
#    u'description(fame)': True,
#    u'description(feel)': True,
#    u'description(finesse)': True,
#    u'description(first)': True,
#    u'description(flu)': True,
#    u'description(foil)': True,
#    u'description(frank)': True,
#    u'description(frostbite)': True,
#    u'description(frosty)': True,
#    u'description(gander)': True,
#    u'description(genevieve)': True,
#    u'description(grove)': True,
#    u'description(guide)': True,
#    u'description(guitar)': True,
#    u'description(guitarist)': True,
#    u'description(hadley)': True,
#    u'description(hall)': True,
#    u'description(horn)': True,
#    u'description(houston)': True,
#    u'description(iceman)': True,
#    u'description(icy)': True,
#    u'description(imagination)': True,
#    u'description(impossible)': True,
#    u'description(includes)': True,
#    u'description(including)': True,
#    u'description(instrumental)': True,
#    u'description(instrumentals)': True,
#    u'description(jazz)': True,
#    u'description(john)': True,
#    u'description(known)': True,
#    u'description(label)': True,
#    u'description(line)': True,
#    u'description(lose)': True,
#    u'description(making)': True,
#    u'description(many)': True,
#    u'description(master)': True,
#    u'description(misery)': True,
#    u'description(mostly)': True,
#    u'description(n)': True,
#    u'description(note)': True,
#    u'description(one)': True,
#    u'description(organ)': True,
#    u'description(originally)': True,
#    u'description(others)': True,
#    u'description(perennially)': True,
#    u'description(perfect)': True,
#    u'description(pitched)': True,
#    u'description(playing)': True,
#    u'description(press)': True,
#    u'description(probably)': True,
#    u'description(provides)': True,
#    u'description(put)': True,
#    u'description(r)': True,
#    u'description(recorded)': True,
#    u'description(recording)': True,
#    u'description(released)': True,
#    u'description(rock)': True,
#    u'description(sax)': True,
#    u'description(second)': True,
#    u'description(sens)': True,
#    u'description(shake)': True,
#    u'description(shiver)': True,
#    u'description(signature)': True,
#    u'description(slow)': True,
#    u'description(small)': True,
#    u'description(smooth)': True,
#    u'description(sno)': True,
#    u'description(song)': True,
#    u'description(sound)': True,
#    u'description(stand)': True,
#    u'description(starter)': True,
#    u'description(style)': True,
#    u'description(suggested)': True,
#    u'description(take)': True,
#    u'description(tape)': True,
#    u'description(telecaster)': True,
#    u'description(tenor)': True,
#    u'description(thaw)': True,
#    u'description(thing)': True,
#    u'description(thirty)': True,
#    u'description(three)': True,
#    u'description(title)': True,
#    u'description(tone)': True,
#    u'description(trend)': True,
#    u'description(truckin)': True,
#    u'description(trumpet)': True,
#    u'description(tune)': True,
#    u'description(two)': True,
#    u'description(unhindered)': True,
#    u'description(unusually)': True,
#    u'description(vocal)': True,
#    u'description(warm)': True,
#    u'description(williams)': True,
#    u'description(wonder)': True,
#    u'description(work)': True,
#    u'description(wrong)': True,
#    u'name(truckin)': True},
#   u''),
#  ({u'description("!))': True,
#    u"description('!))": True,
#    u'description(),)': True,
#    u'description().)': True,
#    u'description(,")': True,
#    u"description(,')": True,
#    u'description(--)': True,
#    u'description(---)': True,
#    u'description(.")': True,
#    u"description(.'')": True,
#    u"description(.')": True,
#    u'description(000)': True,
#    u'description(1)': True,
#    u'description(101)': True,
#    u'description(12)': True,
#    u'description(13)': True,
#    u'description(15)': True,
#    u'description(1520)': True,
#    u'description(18)': True,
#    u'description(2)': True,
#    u'description(20)': True,
#    u'description(26)': True,
#    u'description(27)': True,
#    u'description(3)': True,
#    u'description(4)': True,
#    u'description(500)': True,
#    u'description(6)': True,
#    u'description(700)': True,
#    u'description(95)': True,
#    u'description(ability)': True,
#    u'description(abogado)': True,
#    u'description(accept)': True,
#    u'description(accepted)': True,
#    u'description(account)': True,
#    u'description(act)': True,
#    u'description(adult)': True,
#    u'description(agent)': True,
#    u'description(alone)': True,
#    u'description(also)': True,
#    u'description(amazing)': True,
#    u'description(analysis)': True,
#    u'description(anterioridad)': True,
#    u'description(argument)': True,
#    u'description(aspect)': True,
#    u'description(association)': True,
#    u'description(authentic)': True,
#    u'description(author)': True,
#    u'description(authority)': True,
#    u'description(awesome)': True,
#    u'description(bar)': True,
#    u'description(based)': True,
#    u'description(basic)': True,
#    u'description(bear)': True,
#    u'description(bearer)': True,
#    u'description(bearing)': True,
#    u'description(become)': True,
#    u'description(becoming)': True,
#    u'description(begin)': True,
#    u'description(beginning)': True,
#    u'description(being)': True,
#    u'description(believe)': True,
#    u'description(beyond)': True,
#    u'description(bible)': True,
#    u'description(biblical)': True,
#    u'description(bilezikian)': True,
#    u'description(bill)': True,
#    u'description(bio)': True,
#    u'description(birthed)': True,
#    u'description(blueprint)': True,
#    u'description(body)': True,
#    u'description(book)': True,
#    u'description(born)': True,
#    u'description(breathe)': True,
#    u'description(build)': True,
#    u'description(building)': True,
#    u'description(call)': True,
#    u'description(cannot)': True,
#    u'description(case)': True,
#    u'description(catch)': True,
#    u'description(center)': True,
#    u'description(change)': True,
#    u'description(child)': True,
#    u'description(christ)': True,
#    u'description(christian)': True,
#    u'description(church)': True,
#    u'description(circumstance)': True,
#    u'description(clear)': True,
#    u'description(closely)': True,
#    u'description(closing)': True,
#    u'description(coaching)': True,
#    u'description(coauthor)': True,
#    u'description(coautor)': True,
#    u'description(colaborando)': True,
#    u'description(collective)': True,
#    u'description(com)': True,
#    u'description(come)': True,
#    u'description(communal)': True,
#    u'description(community)': True,
#    u'description(communityfor)': True,
#    u'description(como)': True,
#    u'description(complex)': True,
#    u'description(con)': True,
#    u'description(concert)': True,
#    u'description(conclude)': True,
#    u'description(conflict)': True,
#    u'description(connect)': True,
#    u'description(connection)': True,
#    u'description(consensus)': True,
#    u'description(continues)': True,
#    u'description(convincing)': True,
#    u'description(core)': True,
#    u'description(correlation)': True,
#    u'description(country)': True,
#    u'description(crave)': True,
#    u'description(create)': True,
#    u'description(created)': True,
#    u'description(creation)': True,
#    u'description(creek)': True,
#    u'description(critical)': True,
#    u'description(cross)': True,
#    u'description(cultural)': True,
#    u'description(daughter)': True,
#    u'description(de)': True,
#    u'description(deadly)': True,
#    u'description(deal)': True,
#    u'description(decision)': True,
#    u'description(deep)': True,
#    u'description(deeper)': True,
#    u'description(define)': True,
#    u'description(defined)': True,
#    u'description(defining)': True,
#    u'description(deity)': True,
#    u'description(del)': True,
#    u'description(demonstration)': True,
#    u'description(denomination)': True,
#    u'description(depends)': True,
#    u'description(describes)': True,
#    u'description(desempeno)': True,
#    u'description(determine)': True,
#    u'description(deuteronomy)': True,
#    u'description(develop)': True,
#    u'description(develops)': True,
#    u'description(devoted)': True,
#    u'description(dig)': True,
#    u'description(direct)': True,
#    u'description(directed)': True,
#    u'description(director)': True,
#    u'description(discover)': True,
#    u'description(distinctive)': True,
#    u'description(do)': True,
#    u'description(doctrine)': True,
#    u'description(donahue)': True,
#    u'description(doubt)': True,
#    u'description(dr)': True,
#    u'description(dream)': True,
#    u'description(dundee)': True,
#    u'description(e)': True,
#    u'description(else)': True,
#    u'description(empowers)': True,
#    u'description(en)': True,
#    u'description(enigmatic)': True,
#    u'description(enough)': True,
#    u'description(entire)': True,
#    u'description(esposa)': True,
#    u'description(estate)': True,
#    u'description(eternal)': True,
#    u'description(eternally)': True,
#    u'description(eternity)': True,
#    u'description(even)': True,
#    u'description(every)': True,
#    u'description(evidence)': True,
#    u'description(example)': True,
#    u'description(executive)': True,
#    u'description(existed)': True,
#    u'description(exists)': True,
#    u'description(experience)': True,
#    u'description(explains)': True,
#    u'description(expressed)': True,
#    u'description(expression)': True,
#    u'description(face)': True,
#    u'description(faith)': True,
#    u'description(fallible)': True,
#    u'description(finally)': True,
#    u'description(first)': True,
#    u'description(follower)': True,
#    u'description(forever)': True,
#    u'description(form)': True,
#    u'description(formational)': True,
#    u'description(formerly)': True,
#    u'description(four)': True,
#    u'description(framework)': True,
#    u'description(fue)': True,
#    u'description(fullness)': True,
#    u'description(fully)': True,
#    u'description(gail)': True,
#    u'description(gareth)': True,
#    u'description(gathering)': True,
#    u'description(gene)': True,
#    u'description(generation)': True,
#    u'description(generational)': True,
#    u'description(generic)': True,
#    u'description(genesis)': True,
#    u'description(gentleman)': True,
#    u'description(gilbert)': True,
#    u'description(giving)': True,
#    u'description(glimpse)': True,
#    u'description(god)': True,
#    u'description(godhead)': True,
#    u'description(gone)': True,
#    u'description(good)': True,
#    u'description(group)': True,
#    u'description(grow)': True,
#    u'description(growth)': True,
#    u'description(grupos)': True,
#    u'description(guidance)': True,
#    u'description(haledon)': True,
#    u'description(happens)': True,
#    u'description(health)': True,
#    u'description(hear)': True,
#    u'description(heard)': True,
#    u'description(heart)': True,
#    u'description(help)': True,
#    u'description(helping)': True,
#    u'description(hijos)': True,
#    u'description(hoffman)': True,
#    u'description(horizontal)': True,
#    u'description(horizontaljust)': True,
#    u'description(hovering)': True,
#    u'description(however)': True,
#    u'description(human)': True,
#    u'description(humanity)': True,
#    u'description(hunger)': True,
#    u'description(husband)': True,
#    u'description(icenogle)': True,
#    u'description(idea)': True,
#    u'description(identify)': True,
#    u'description(identity)': True,
#    u'description(ignore)': True,
#    u'description(illinois)': True,
#    u'description(image)': True,
#    u'description(impact)': True,
#    u'description(implementacion)': True,
#    u'description(implication)': True,
#    u'description(important)': True,
#    u'description(incarnate)': True,
#    u'description(include)': True,
#    u'description(including)': True,
#    u'description(independence)': True,
#    u'description(individual)': True,
#    u'description(individuality)': True,
#    u'description(ing)': True,
#    u'description(integrate)': True,
#    u'description(interested)': True,
#    u'description(intersect)': True,
#    u'description(intrinsic)': True,
#    u'description(israel)': True,
#    u'description(jersey)': True,
#    u'description(jesus)': True,
#    u'description(john)': True,
#    u'description(journey)': True,
#    u'description(judge)': True,
#    u'description(jury)': True,
#    u'description(kent)': True,
#    u'description(keri)': True,
#    u'description(keriwyattkent)': True,
#    u'description(kind)': True,
#    u'description(knit)': True,
#    u'description(know)': True,
#    u'description(la)': True,
#    u'description(lacking)': True,
#    u'description(lady)': True,
#    u'description(law)': True,
#    u'description(lead)': True,
#    u'description(leader)': True,
#    u'description(learn)': True,
#    u'description(let)': True,
#    u'description(libro)': True,
#    u'description(life)': True,
#    u'description(like)': True,
#    u'description(likeness)': True,
#    u'description(listen)': True,
#    u'description(live)': True,
#    u'description(long)': True,
#    u'description(lord)': True,
#    u'description(made)': True,
#    u'description(make)': True,
#    u'description(man)': True,
#    u'description(many)': True,
#    u'description(massive)': True,
#    u'description(matthew)': True,
#    u'description(mature)': True,
#    u'description(meadowbrook)': True,
#    u'description(mean)': True,
#    u'description(meet)': True,
#    u'description(member)': True,
#    u'description(men)': True,
#    u'description(miembro)': True,
#    u'description(might)': True,
#    u'description(mind)': True,
#    u'description(ministerio)': True,
#    u'description(ministerios)': True,
#    u'description(ministry)': True,
#    u'description(model)': True,
#    u'description(move)': True,
#    u'description(much)': True,
#    u'description(mundial)': True,
#    u'description(must)': True,
#    u'description(name)': True,
#    u'description(natural)': True,
#    u'description(nature)': True,
#    u'description(ness)': True,
#    u'description(never)': True,
#    u'description(new)': True,
#    u'description(nobody)': True,
#    u'description(north)': True,
#    u'description(note)': True,
#    u'description(nothing)': True,
#    u'description(noticed)': True,
#    u'description(nueva)': True,
#    u'description(objectively)': True,
#    u'description(obsessed)': True,
#    u'description(offer)': True,
#    u'description(one)': True,
#    u'description(oneness)': True,
#    u'description(ontological)': True,
#    u'description(organizational)': True,
#    u'description(orthodox)': True,
#    u'description(others)': True,
#    u'description(ounce)': True,
#    u'description(oxygen)': True,
#    u'description(part)': True,
#    u'description(pastor)': True,
#    u'description(people)': True,
#    u'description(pequenos)': True,
#    u'description(per)': True,
#    u'description(person)': True,
#    u'description(personal)': True,
#    u'description(picture)': True,
#    u'description(place)': True,
#    u'description(planificacion)': True,
#    u'description(plurality)': True,
#    u'description(powerful)': True,
#    u'description(practice)': True,
#    u'description(practicing)': True,
#    u'description(prayed)': True,
#    u'description(preach)': True,
#    u'description(present)': True,
#    u'description(previamente)': True,
#    u'description(principal)': True,
#    u'description(process)': True,
#    u'description(proclaim)': True,
#    u'description(proclaims)': True,
#    u'description(proof)': True,
#    u'description(prove)': True,
#    u'description(proven)': True,
#    u'description(provide)': True,
#    u'description(provides)': True,
#    u'description(purpose)': True,
#    u'description(read)': True,
#    u'description(reality)': True,
#    u'description(recruit)': True,
#    u'description(reference)': True,
#    u'description(reflection)': True,
#    u'description(relational)': True,
#    u'description(relationship)': True,
#    u'description(remain)': True,
#    u'description(remarkable)': True,
#    u'description(render)': True,
#    u'description(representing)': True,
#    u'description(required)': True,
#    u'description(requires)': True,
#    u'description(reside)': True,
#    u'description(respond)': True,
#    u'description(responsibility)': True,
#    u'description(rest)': True,
#    u'description(result)': True,
#    u'description(retreat)': True,
#    u'description(revealing)': True,
#    u'description(review)': True,
#    u'description(reviewing)': True,
#    u'description(rightly)': True,
#    u'description(robinson)': True,
#    u'description(rus)': True,
#    u'description(sacrilege)': True,
#    u'description(said)': True,
#    u'description(say)': True,
#    u'description(schizoid)': True,
#    u'description(scot)': True,
#    u'description(scripture)': True,
#    u'description(se)': True,
#    u'description(seasoned)': True,
#    u'description(second)': True,
#    u'description(see)': True,
#    u'description(seemingly)': True,
#    u'description(senior)': True,
#    u'description(sense)': True,
#    u'description(seven)': True,
#    u'description(several)': True,
#    u'description(share)': True,
#    u'description(shared)': True,
#    u'description(shatters)': True,
#    u'description(show)': True,
#    u'description(simple)': True,
#    u'description(simply)': True,
#    u'description(sin)': True,
#    u'description(since)': True,
#    u'description(singularity)': True,
#    u'description(singularly)': True,
#    u'description(size)': True,
#    u'description(skilled)': True,
#    u'description(small)': True,
#    u'description(soberly)': True,
#    u'description(society)': True,
#    u'description(sociological)': True,
#    u'description(something)': True,
#    u'description(son)': True,
#    u'description(soon)': True,
#    u'description(sought)': True,
#    u'description(spanish)': True,
#    u'description(speak)': True,
#    u'description(speaker)': True,
#    u'description(spirit)': True,
#    u'description(spiritual)': True,
#    u'description(stand)': True,
#    u'description(statement)': True,
#    u'description(story)': True,
#    u'description(strategy)': True,
#    u'description(study)': True,
#    u'description(su)': True,
#    u'description(support)': True,
#    u'description(sus)': True,
#    u'description(tell)': True,
#    u'description(term)': True,
#    u'description(theologian)': True,
#    u'description(theological)': True,
#    u'description(theology)': True,
#    u'description(theologythat)': True,
#    u'description(thing)': True,
#    u'description(think)': True,
#    u'description(third)': True,
#    u'description(thirteen)': True,
#    u'description(thorough)': True,
#    u'description(three)': True,
#    u'description(thriving)': True,
#    u'description(time)': True,
#    u'description(titulado)': True,
#    u'description(today)': True,
#    u'description(together)': True,
#    u'description(top)': True,
#    u'description(toward)': True,
#    u'description(train)': True,
#    u'description(trans)': True,
#    u'description(transcendant)': True,
#    u'description(transforming)': True,
#    u'description(trinitarian)': True,
#    u'description(trinity)': True,
#    u'description(triune)': True,
#    u'description(true)': True,
#    u'description(trust)': True,
#    u'description(truth)': True,
#    u'description(two)': True,
#    u'description(u)': True,
#    u'description(underpinnings)': True,
#    u'description(understand)': True,
#    u'description(understood)': True,
#    u'description(unique)': True,
#    u'description(universal)': True,
#    u'description(unless)': True,
#    u'description(unpacks)': True,
#    u'description(value)': True,
#    u'description(verdict)': True,
#    u'description(vertical)': True,
#    u'description(view)': True,
#    u'description(vision)': True,
#    u'description(vital)': True,
#    u'description(vitality)': True,
#    u'description(want)': True,
#    u'description(water)': True,
#    u'description(wca)': True,
#    u'description(well)': True,
#    u'description(west)': True,
#    u'description(whatever)': True,
#    u'description(whenever)': True,
#    u'description(whose)': True,
#    u'description(willow)': True,
#    u'description(window)': True,
#    u'description(within)': True,
#    u'description(without)': True,
#    u'description(woman)': True,
#    u'description(word)': True,
#    u'description(work)': True,
#    u'description(world)': True,
#    u'description(worldwide)': True,
#    u'description(would)': True,
#    u'description(write)': True,
#    u'description(written)': True,
#    u'description(www)': True,
#    u'description(wyatt)': True,
#    u'description(yet)': True,
#    u'description(youll)': True,
#    u'description(youve)': True,
#    u'name(building)': True,
#    u'name(church)': True,
#    u'name(group)': True,
#    u'name(small)': True},
#   u''),
#  ({u'description(clothing)': True,
#    u'description(pant)': True,
#    u'description(pleated)': True,
#    u'description(tall)': True,
#    u'name(amazon)': True,
#    u'name(amp)': True,
#    u'name(big)': True,
#    u'name(com)': True,
#    u'name(docker)': True,
#    u'name(khaki)': True,
#    u'name(men)': True,
#    u'name(signature)': True},
#   u'Signature Khaki Pleated Pant with Modern Comfort Waistband'),
#  ({u'description("...)': True,
#    u'description().)': True,
#    u'description(.")': True,
#    u'description(....)': True,
#    u'description(1986)': True,
#    u'description(accessible)': True,
#    u'description(ancient)': True,
#    u'description(anyone)': True,
#    u'description(artistic)': True,
#    u'description(aspect)': True,
#    u'description(background)': True,
#    u'description(beginning)': True,
#    u'description(book)': True,
#    u'description(challenge)': True,
#    u'description(city)': True,
#    u'description(companion)': True,
#    u'description(complex)': True,
#    u'description(concrete)': True,
#    u'description(cover)': True,
#    u'description(culture)': True,
#    u'description(cup)': True,
#    u'description(designed)': True,
#    u'description(discussion)': True,
#    u'description(engages)': True,
#    u'description(example)': True,
#    u'description(frequent)': True,
#    u'description(great)': True,
#    u'description(historical)': True,
#    u'description(history)': True,
#    u'description(idea)': True,
#    u'description(illustrate)': True,
#    u'description(illustration)': True,
#    u'description(interested)': True,
#    u'description(introduction)': True,
#    u'description(latin)': True,
#    u'description(literary)': True,
#    u'description(made)': True,
#    u'description(make)': True,
#    u'description(numerous)': True,
#    u'description(particularly)': True,
#    u'description(power)': True,
#    u'description(quotation)': True,
#    u'description(reading)': True,
#    u'description(religious)': True,
#    u'description(review)': True,
#    u'description(rise)': True,
#    u'description(rome)': True,
#    u'description(school)': True,
#    u'description(seriously)': True,
#    u'description(serve)': True,
#    u'description(sh)': True,
#    u'description(still)': True,
#    u'description(stimulating)': True,
#    u'description(strength)': True,
#    u'description(student)': True,
#    u'description(study)': True,
#    u'description(suitable)': True,
#    u'description(thoughtful)': True,
#    u'description(today)': True,
#    u'description(u)': True,
#    u'description(university)': True,
#    u'description(use)': True,
#    u'description(well)': True,
#    u'description(world)': True,
#    u'description(writer)': True,
#    u'description(written)': True,
#    u'name(culture)': True,
#    u'name(introduction)': True,
#    u'name(roman)': True,
#    u'name(rome)': True,
#    u'name(world)': True},
#   u'')]

# %%
corpus = ProductCorpus('products.csv')

# %%
corpus.categories()
# Out:
# {u' Android Tablets and Accessories',
#  u' Apple Hardware and Accessories ',
#  u' Apple Laptops',
#  u' Apple iPads and Accessories',
#  u' Desktop Hardware and Accessories',
#  u' Desktops',
#  u' Laptop Hardware and Accessories ',
#  u' Laptops',
#  u' Monitors',
#  u' Palm',
#  u' Printers',
#  u' Software',
#  u'NULL'}
